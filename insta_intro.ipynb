# %%
print("my name is MOHIT and my fevorite app is chat gpt and google gemini")
# Out:
# my name is MOHIT and my fevorite app is chat gpt and google gemini

# %%
print('Welcome to Data Science with Python!')
# Out:
# Welcome to Data Science with Python!
