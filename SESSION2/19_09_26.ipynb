# %%
item_price =250
delivery_fee=30
coupon_discount=20
print(item_price,"\n",delivery_fee,"\n",coupon_discount)
# Out:
# 250
#  30
#  20

# %%
''' 
    this block of code shows use is your product elgible for free delivery or not, 
    you only has to put your total bill amount.
'''
Flipkart_products_price=int(input("enter your product price :"))
if Flipkart_products_price>1000:
    print("Eligible for free delivery")
else:
    print("Delivery charges apply")


# put you Product price in the input box or pop up in the form of integer
# Out:
# Delivery charges apply
# ' \n    this block of code shows use is your product elgible for free delivery or not, \n    you only has to put your total bill amount.\n'

# %%
team_name=input("Enter Your Player Name:")
runs_scored =int(input("Enter Youre Playes Score:"))
overs_played=int(input("ENTER YOURE PLATES PLAYED OVERS:"))
print(team_name)
print(runs_scored)
print(overs_played)
# Out:
# mohit
# 55
# 4
