# %% [markdown]
# 1. Write a Python script that takes your current Spotify listening time in minutes and checks if it is abo ve 120 minutes; if yes, print 'You are a true music fan!', otherwise print 'Keep listening!'.

# %%
current_Sportfy_time=int(input("Enter your Spotify listening Time : "))
if current_Sportfy_time>120:
    print("You are a true music fan!")
else:
    print("Keep Listening !")
# Out:
# You are a true music fan!

# %% [markdown]
# 2. Create a Python program that asks the user to enter their Zomato order amount and checks if it is above 300; if yes, print 'Eligible for free delivery', else print 'Delivery charges apply'.

# %%
Z_order_amount=float(input("Enter the youre oder amount : "))
if Z_order_amount>300:
    print("Eligible for free Delivery")
else:
    print("Delivery Charges apply")
# Out:
# Eligible for free Delivery

# %% [markdown]
# 3. Build a Python script that takes your Flipkart cart total and applies the following logic: if total > 2000, print 'You get a 10% discount'; elif total > 1000, print 'You get a 5% discount'; else print 'No discount available'.

# %%
Flip_order_amount=float(input("Enter the youre oder amount : "))
if Flip_order_amount>2000:
    print('You get a 10% Discount')
elif Flip_order_amount>1000:
    print('You get a 5% Discount')
else:
    print("No discount available on youre order value plear increse the order value ")
# Out:
# You get a 10% Discount

# %% [markdown]
# 4. Write a Python program that asks the user to enter their IPL fantasy team points and uses nested if-else statements to print: 'Champion' if points > 800, 'Top Performer' if points between 500 and 800, 'Keep Trying' otherwise.<br><br><em><strong>Hint:</strong> Use nested if-else blocks to check the ranges.</em>

# %%
IPL_fantacy_Team=float(input("Enter Your IPL Fantacy team Points: "))
if IPL_fantacy_Team>800:
    print("Champion")
# elif IPL_fantacy_Team in range(500,801):
elif IPL_fantacy_Team>=500:
    if IPL_fantacy_Team<=800:
        print("Top performer")
else:
    print("Keep Trying")
# Out:
# Top performer
